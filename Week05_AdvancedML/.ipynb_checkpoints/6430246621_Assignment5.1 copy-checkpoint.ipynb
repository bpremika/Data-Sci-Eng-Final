# %%
# !pip3 install numpy
# !pip3 install pandas
# !pip3 install scikit-learn
# !pip3 install mlflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (1.26.3)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from pandas) (1.26.3)
# Requirement already satisfied: tzdata>=2022.7 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (1.4.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.12.0)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlflow in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (2.10.2)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (4.25.2)
# Requirement already satisfied: packaging<24 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (23.2)
# Requirement already satisfied: Flask<4 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cloudpickle<4 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.0.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (8.1.7)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (7.0.1)
# Requirement already satisfied: gunicorn<22 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (21.2.0)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (7.0.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.1.3)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.1.41)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (2.0.25)
# Requirement already satisfied: scikit-learn<2 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (1.4.0)
# Requirement already satisfied: matplotlib<4 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.8.2)
# Requirement already satisfied: pandas<3 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (2.2.0)
# Requirement already satisfied: entrypoints<1 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (0.4)
# Requirement already satisfied: markdown<4,>=3.3 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.5.2)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (6.0.1)
# Requirement already satisfied: scipy<2 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (1.12.0)
# Requirement already satisfied: pytz<2024 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (2023.3.post1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (15.0.0)
# Requirement already satisfied: numpy<2 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (1.26.3)
# Requirement already satisfied: querystring-parser<2 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from mlflow) (0.4.4)
# Requirement already satisfied: Mako in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from alembic!=1.10.0,<2->mlflow) (4.9.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from docker<8,>=4.0.0->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from Flask<4->mlflow) (1.7.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from Flask<4->mlflow) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from Flask<4->mlflow) (2.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from gitpython<4,>=2.1.0->mlflow) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow) (5.0.1)
# Requirement already satisfied: zipp>=0.5 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (4.48.1)
# Requirement already satisfied: pillow>=8 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (10.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (6.1.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from pandas<3->mlflow) (2023.4)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib<4->mlflow) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.17.3->mlflow) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.17.3->mlflow) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.17.3->mlflow) (3.3.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from scikit-learn<2->mlflow) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/premikayutinatorn/Library/Python/3.9/lib/python/site-packages (from scikit-learn<2->mlflow) (3.2.0)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/pvateekul/2110446_DSDE_2023s2/main/code/Week03_ML/mushroom2020_dataset.csv')

# %%
df.isnull().sum()
# Out:
# id                               0
# label                           60
# cap-shape                        0
# cap-surface                     27
# bruises                         99
# odor                            99
# gill-attachment                 99
# gill-spacing                   130
# gill-size                      121
# stalk-shape                    121
# stalk-root                      31
# stalk-surface-above-ring        31
# stalk-surface-below-ring        31
# veil-type                       62
# ring-number                     62
# ring-type                       62
# spore-print-color               56
# population                      56
# habitat                         31
# cap-color-rate                  27
# gill-color-rate                121
# veil-color-rate                 62
# stalk-color-above-ring-rate     31
# stalk-color-below-ring-rate     62
# dtype: int64

# %% [markdown]
# Data Preparation

# %%
df.dropna(subset=['label'], inplace=True)
df.shape
# Out:
# (5764, 24)

# %%
drop_columns = ['id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate','stalk-root', 'stalk-surface-above-ring',
 'stalk-surface-below-ring', 'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type']

df.drop(columns=drop_columns, inplace=True)
df.shape
# Out:
# (5764, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5764 entries, 0 to 5823
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   label              5764 non-null   object
#  1   cap-shape          5764 non-null   object
#  2   cap-surface        5737 non-null   object
#  3   bruises            5665 non-null   object
#  4   odor               5665 non-null   object
#  5   stalk-shape        5643 non-null   object
#  6   ring-number        5702 non-null   object
#  7   ring-type          5702 non-null   object
#  8   spore-print-color  5708 non-null   object
#  9   population         5708 non-null   object
#  10  habitat            5733 non-null   object
#  11  cap-color-rate     5737 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 585.4+ KB

# %%
mapping_dict = {
    "label": {
        "p": 0,
        "e": 1,
    },
}

df = df.replace(mapping_dict)
df.label.value_counts()
# Out:
# /var/folders/vc/c5yh3t2s6tgc117z_ws0m1tw0000gn/T/ipykernel_77131/3373781591.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(mapping_dict)
# label
# 0    3660
# 1    2104
# Name: count, dtype: int64

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline

cat_cols=['cap-surface','bruises','odor','stalk-shape','ring-number','ring-type','spore-print-color','population','habitat']
num_cols=['cap-color-rate']

num_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='mean')),
    ('scale', StandardScaler())])

cat_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('one-hot',OneHotEncoder(handle_unknown='ignore', sparse_output=False))])
df
# Out:
#       label cap-shape cap-surface bruises odor stalk-shape ring-number  \
# 0         0         x           s       t    p           e           o
# 1         1         x           s       t    a           e           o
# 2         1         b           s       t    l           e           o
# 3         0         x           y       t    p           e           o
# 4         1         x           s       f    n           t           o
# ...     ...       ...         ...     ...  ...         ...         ...
# 5819      1         k           s       f    n           e           o
# 5820      1         x           s       f    n           e           o
# 5821      1         f           s       f    n           e           o
# 5822      0         k           y       f    y           t           o
# 5823      1         x           s       f    n           e           o
#
#      ring-type spore-print-color population habitat  cap-color-rate
# 0            p                 k          s       u             1.0
# 1            p                 n          n       g             2.0
# 2            p                 n          n       m             3.0
# 3            p                 k          s       u             3.0
# 4            e                 n          a       g             4.0
# ...        ...               ...        ...     ...             ...
# 5819         p                 b          c       l             1.0
# 5820         p                 b          v       l             1.0
# 5821         p                 b          c       l             1.0
# 5822         e                 w          v       l             1.0
# 5823         p                 o          c       l             1.0
#
# [5764 rows x 12 columns]

# %%
from sklearn.compose import ColumnTransformer

col_trans = ColumnTransformer(transformers=[
    ('num_pipeline', num_pipeline, num_cols),
    ('cat_pipeline', cat_pipeline, cat_cols)],
    n_jobs=-1)

col_trans
# Out:
# ColumnTransformer(n_jobs=-1,
#                   transformers=[('num_pipeline',
#                                  Pipeline(steps=[('impute', SimpleImputer()),
#                                                  ('scale', StandardScaler())]),
#                                  ['cap-color-rate']),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('one-hot',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['cap-surface', 'bruises', 'odor',
#                                   'stalk-shape', 'ring-number', 'ring-type',
#                                   'spore-print-color', 'population',
#                                   'habitat'])])

# %%
from sklearn.model_selection import train_test_split
y = df.pop('label')
x = df

x_train,x_test,y_train,y_test = train_test_split(x,y,stratify=y,test_size=0.2, random_state=2020)
print(x_train.shape)
print(x_test.shape)
# Out:
# (4611, 11)
# (1153, 11)

# %% [markdown]
# Random Forest

# %%
x_train
# Out:
#      cap-shape cap-surface bruises odor stalk-shape ring-number ring-type  \
# 3526         f           y       t    n           e           t         e
# 1214         f           y       t    n           t           o         p
# 1841         f           y       t    n           t           o         p
# 5548         k           s       f    f           t           o         e
# 3379         x           y       t    n           e           t         e
# ...        ...         ...     ...  ...         ...         ...       ...
# 2647         x           y       f    f           e           o         l
# 5265         k           y       f    y           t           o         e
# 5015         x           s       f    n           e           t         p
# 356          x           y       t    n           t           o         p
# 2942         f           y       f    f           e         NaN       NaN
#
#      spore-print-color population habitat  cap-color-rate
# 3526                 w          c       w             5.0
# 1214                 k          y       d             5.0
# 1841                 n          v       d             5.0
# 5548                 w          v       d             1.0
# 3379                 w          c       w             1.0
# ...                ...        ...     ...             ...
# 2647                 h          y       d             4.0
# 5265                 w          v       d             5.0
# 5015                 w          n       g             3.0
# 356                  k          y       d             5.0
# 2942               NaN        NaN       d             2.0
#
# [4611 rows x 11 columns]

# %%
import mlflow
import mlflow.sklearn
from sklearn.metrics import f1_score, accuracy_score, classification_report

# %%
from sklearn.ensemble import RandomForestClassifier

local_registry = "sqlite:///mlruns.db"
mlflow.set_tracking_uri(local_registry)
experiment_id = mlflow.set_experiment('test_experiment')

def eval_metrics(actual, pred):
    accuracy = accuracy_score(actual, pred)
    return accuracy

def train_model(criterion, max_depth, min_samples_leaf,n_estimators):

    # Starting the Experiement
    with mlflow.start_run():

        # Model building
        model = RandomForestClassifier(criterion=criterion, max_depth= max_depth, min_samples_leaf = min_samples_leaf,
                                        n_estimators = n_estimators,random_state=2020)
        model_pipeline = Pipeline(steps=[
            ('col_trans', col_trans),
            ('model', model)
        ])
        model_pipeline.fit(x_train, y_train)
        y_pred = model_pipeline.predict(x_test)

        (accuracy) = eval_metrics(y_test, y_pred)

        print('Decirion tree (criterion=%s, max_depth=%d, min_samples_leaf=%d, n_estimators=%d):'%(criterion, max_depth, min_samples_leaf, n_estimators))
        print('Accuracy: {:.4f}'.format(accuracy))

        # Logging Parameters
        mlflow.log_param("criterion", criterion)
        mlflow.log_param("max_depth", max_depth)
        mlflow.log_param("min_samples_leaf", min_samples_leaf)
        mlflow.log_param("n_estimators", n_estimators)

        # Logging Metrics
        mlflow.log_metric("accuracy", accuracy_score(y_test, y_pred))

        # Model Logging
        mlflow.sklearn.log_model(model_pipeline, 'model')

        return model_pipeline

# %%
critetion = ['gini','entropy']
max_depth = [2,3,6]
min_samples_leaf = [2,5,10]
n_estimators =[100,200]

for i in range(len(critetion)):
    for j in range(len(max_depth)):
        for k in range(len(min_samples_leaf)):
            for l in range(len(n_estimators)):
                train_model(critetion[i], max_depth[j], min_samples_leaf[k], n_estimators[l])
# Out:
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9714
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9705
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9714
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9705
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9705
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9696
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9792
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9748
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9792
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9748
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9766
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9748
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9991
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9991
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9991
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9991
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9974
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9991
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9766
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9766
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9766
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9766
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9748
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9766
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9991
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9991
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9991
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9991
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9983
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9983

# %%
best_run_df = mlflow.search_runs(order_by=['metrics.accuracy DESC'], max_results=10)
best_run_df
# Out:
#                              run_id experiment_id    status  \
# 0  4c7a580b179041379411a0828c76132a             1  FINISHED
# 1  471b2e800a9642afb69be63fae0ca896             1  FINISHED
# 2  dfb0dcfa51c240c5b07bf2d1b82be49e             1  FINISHED
# 3  0ec763558fa04d9aadde81772b3aa472             1  FINISHED
# 4  6147c7a6aafe466bbc2ed716be4de13c             1  FINISHED
# 5  624da1dfb2b64b4f92ebd39b094ae89c             1  FINISHED
# 6  ceb2a3760d9d40aeb334273f0d1f61de             1  FINISHED
# 7  dbaef3d74f8a46e9bf8b03c409fe395b             1  FINISHED
# 8  c6408f563e524514a9d3f377a440857d             1  FINISHED
# 9  b716a933f9d7417f9d16522e2434447c             1  FINISHED
#
#                                         artifact_uri  \
# 0  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 1  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 2  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 3  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 4  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 5  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 6  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 7  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 8  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 9  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
#
#                         start_time                         end_time  \
# 0 2024-02-12 07:32:28.596000+00:00 2024-02-12 07:32:29.939000+00:00
# 1 2024-02-12 07:32:27.358000+00:00 2024-02-12 07:32:28.594000+00:00
# 2 2024-02-12 07:32:26.083000+00:00 2024-02-12 07:32:27.355000+00:00
# 3 2024-02-12 07:32:24.796000+00:00 2024-02-12 07:32:26.080000+00:00
# 4 2024-02-12 07:32:07.817000+00:00 2024-02-12 07:32:09.227000+00:00
# 5 2024-02-12 07:32:05.255000+00:00 2024-02-12 07:32:06.604000+00:00
# 6 2024-02-12 07:32:04.023000+00:00 2024-02-12 07:32:05.253000+00:00
# 7 2024-02-12 07:32:02.574000+00:00 2024-02-12 07:32:04.020000+00:00
# 8 2024-02-12 07:32:01.250000+00:00 2024-02-12 07:32:02.571000+00:00
# 9 2024-02-12 07:30:29.811000+00:00 2024-02-12 07:30:31.126000+00:00
#
#    metrics.accuracy params.min_samples_leaf params.max_depth  \
# 0          0.999133                       5                6
# 1          0.999133                       5                6
# 2          0.999133                       2                6
# 3          0.999133                       2                6
# 4          0.999133                      10                6
# 5          0.999133                       5                6
# 6          0.999133                       5                6
# 7          0.999133                       2                6
# 8          0.999133                       2                6
# 9          0.999133                       5                6
#
#   params.n_estimators params.criterion   tags.mlflow.runName  \
# 0                 200          entropy     unequaled-dog-418
# 1                 100          entropy    righteous-vole-191
# 2                 200          entropy   exultant-grouse-320
# 3                 100          entropy  agreeable-donkey-889
# 4                 200             gini         burly-koi-585
# 5                 200             gini   monumental-skunk-56
# 6                 100             gini  thoughtful-conch-802
# 7                 200             gini       powerful-ox-490
# 8                 100             gini    flawless-quail-992
# 9                 200          entropy      bouncy-trout-930
#
#                        tags.mlflow.log-model.history tags.mlflow.source.type  \
# 0  [{"run_id": "4c7a580b179041379411a0828c76132a"...                   LOCAL
# 1  [{"run_id": "471b2e800a9642afb69be63fae0ca896"...                   LOCAL
# 2  [{"run_id": "dfb0dcfa51c240c5b07bf2d1b82be49e"...                   LOCAL
# 3  [{"run_id": "0ec763558fa04d9aadde81772b3aa472"...                   LOCAL
# 4  [{"run_id": "6147c7a6aafe466bbc2ed716be4de13c"...                   LOCAL
# 5  [{"run_id": "624da1dfb2b64b4f92ebd39b094ae89c"...                   LOCAL
# 6  [{"run_id": "ceb2a3760d9d40aeb334273f0d1f61de"...                   LOCAL
# 7  [{"run_id": "dbaef3d74f8a46e9bf8b03c409fe395b"...                   LOCAL
# 8  [{"run_id": "c6408f563e524514a9d3f377a440857d"...                   LOCAL
# 9  [{"run_id": "b716a933f9d7417f9d16522e2434447c"...                   LOCAL
#
#     tags.mlflow.user                            tags.mlflow.source.name
# 0  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 1  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 2  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 3  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 4  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 5  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 6  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 7  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 8  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 9  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...

# %%
run_id = str(best_run_df.loc[0, 'run_id'])
print('run_id: ', run_id)

run_id = str(best_run_df.loc[0, 'run_id'])
model_uri = f"runs:/{run_id}/model"
print('model_uri: ', model_uri)
# Out:
# run_id:  4c7a580b179041379411a0828c76132a
# model_uri:  runs:/4c7a580b179041379411a0828c76132a/model

# %%
# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(model_uri=f"runs:/{run_id}/model")

# Predict on a Pandas DataFrame.
predicted = loaded_model.predict(pd.DataFrame(x_test))

print(classification_report(y_test, predicted, target_names=['0', '1'], digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9986    0.9993       732
#            1     0.9976    1.0000    0.9988       421
#
#     accuracy                         0.9991      1153
#    macro avg     0.9988    0.9993    0.9991      1153
# weighted avg     0.9991    0.9991    0.9991      1153

# %%
from sklearn.metrics import classification_report,confusion_matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, predicted,labels = [0,1]))
# Out:
# Confusion Matrix:
# [[731   1]
#  [  0 421]]
