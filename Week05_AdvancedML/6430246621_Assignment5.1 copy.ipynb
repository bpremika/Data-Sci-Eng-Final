# %%
# %pip install numpy
# %pip install pandas
# %pip install scikit-learn
# %pip install mlflow
# Out:
# Requirement already satisfied: numpy in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.13.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.0 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.2-cp312-cp312-macosx_12_0_arm64.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 6.3 MB/s eta 0:00:00m eta 0:00:010:0101
# Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.2/301.2 kB 5.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading scipy-1.13.0-cp312-cp312-macosx_12_0_arm64.whl (30.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.4/30.4 MB 6.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.0 scikit-learn-1.4.2 scipy-1.13.0 threadpoolctl-3.4.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting mlflow
#   Downloading mlflow-2.12.1-py3-none-any.whl.metadata (29 kB)
# Collecting Flask<4 (from mlflow)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting click<9,>=7.0 (from mlflow)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting cloudpickle<4 (from mlflow)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting entrypoints<1 (from mlflow)
#   Downloading entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow)
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.3-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting importlib-metadata!=4.7.0,<8,>=3.7.0 (from mlflow)
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting markdown<4,>=3.3 (from mlflow)
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: matplotlib<4 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from mlflow) (3.8.4)
# Requirement already satisfied: numpy<2 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from mlflow) (1.26.4)
# Requirement already satisfied: packaging<25 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from mlflow) (24.0)
# Requirement already satisfied: pandas<3 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from mlflow) (2.2.2)
# Collecting protobuf<6,>=3.12.0 (from mlflow)
#   Downloading protobuf-5.26.1-cp37-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting pyarrow<16,>=4.0.0 (from mlflow)
#   Downloading pyarrow-15.0.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Requirement already satisfied: pytz<2025 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from mlflow) (2024.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from mlflow) (6.0.1)
# Collecting querystring-parser<2 (from mlflow)
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl.metadata (559 bytes)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from mlflow) (2.31.0)
# Requirement already satisfied: scikit-learn<2 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from mlflow) (1.4.2)
# Requirement already satisfied: scipy<2 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from mlflow) (1.13.0)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Downloading SQLAlchemy-2.0.29-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow)
#   Downloading sqlparse-0.5.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: Jinja2<4,>=2.11 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from mlflow) (3.1.3)
# Collecting gunicorn<22 (from mlflow)
#   Downloading gunicorn-21.2.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading Mako-1.3.3-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4 (from alembic!=1.10.0,<2->mlflow)
#   Downloading typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow) (2.2.1)
# Collecting Werkzeug>=3.0.0 (from Flask<4->mlflow)
#   Downloading werkzeug-3.0.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting itsdangerous>=2.1.2 (from Flask<4->mlflow)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting blinker>=1.6.2 (from Flask<4->mlflow)
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting aniso8601<10,>=8 (from graphene<4->mlflow)
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Collecting zipp>=0.5 (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow)
#   Downloading zipp-3.18.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from matplotlib<4->mlflow) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from matplotlib<4->mlflow) (1.4.5)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from matplotlib<4->mlflow) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from matplotlib<4->mlflow) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from matplotlib<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: six in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/opt/certifi/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow) (2024.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages (from scikit-learn<2->mlflow) (3.4.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading mlflow-2.12.1-py3-none-any.whl (20.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 6.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 5.0 MB/s eta 0:00:007.0 MB/s eta 0:00:01
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 3.7 MB/s eta 0:00:00
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading docker-7.0.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.6/147.6 kB 4.1 MB/s eta 0:00:00
# Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 5.4 MB/s eta 0:00:00
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 5.2 MB/s eta 0:00:00m eta 0:00:01
# Downloading graphene-3.3-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 5.7 MB/s eta 0:00:00
# Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 4.9 MB/s eta 0:00:00
# Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 5.7 MB/s eta 0:00:00
# Downloading protobuf-5.26.1-cp37-abi3-macosx_10_9_universal2.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.0/404.0 kB 6.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading pyarrow-15.0.2-cp312-cp312-macosx_11_0_arm64.whl (24.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 6.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Downloading SQLAlchemy-2.0.29-cp312-cp312-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 6.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading sqlparse-0.5.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.8 MB/s eta 0:00:00
# Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.3 MB/s eta 0:00:00
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.0 MB/s eta 0:00:00
# Downloading graphql_core-3.2.3-py3-none-any.whl (202 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 5.0 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Downloading werkzeug-3.0.2-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.8/226.8 kB 4.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading zipp-3.18.1-py3-none-any.whl (8.2 kB)
# Downloading Mako-1.3.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 3.8 MB/s eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: aniso8601, zipp, Werkzeug, typing-extensions, sqlparse, smmap, querystring-parser, pyarrow, protobuf, markdown, Mako, itsdangerous, gunicorn, graphql-core, entrypoints, cloudpickle, click, blinker, sqlalchemy, importlib-metadata, graphql-relay, gitdb, Flask, docker, graphene, gitpython, alembic, mlflow
# Successfully installed Flask-3.0.3 Mako-1.3.3 Werkzeug-3.0.2 alembic-1.13.1 aniso8601-9.0.1 blinker-1.7.0 click-8.1.7 cloudpickle-3.0.0 docker-7.0.0 entrypoints-0.4 gitdb-4.0.11 gitpython-3.1.43 graphene-3.3 graphql-core-3.2.3 graphql-relay-3.2.0 gunicorn-21.2.0 importlib-metadata-7.1.0 itsdangerous-2.2.0 markdown-3.6 mlflow-2.12.1 protobuf-5.26.1 pyarrow-15.0.2 querystring-parser-1.2.4 smmap-5.0.1 sqlalchemy-2.0.29 sqlparse-0.5.0 typing-extensions-4.11.0 zipp-3.18.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/pvateekul/2110446_DSDE_2023s2/main/code/Week03_ML/mushroom2020_dataset.csv')

# %%
df.isnull().sum()
# Out:
# id                               0
# label                           60
# cap-shape                        0
# cap-surface                     27
# bruises                         99
# odor                            99
# gill-attachment                 99
# gill-spacing                   130
# gill-size                      121
# stalk-shape                    121
# stalk-root                      31
# stalk-surface-above-ring        31
# stalk-surface-below-ring        31
# veil-type                       62
# ring-number                     62
# ring-type                       62
# spore-print-color               56
# population                      56
# habitat                         31
# cap-color-rate                  27
# gill-color-rate                121
# veil-color-rate                 62
# stalk-color-above-ring-rate     31
# stalk-color-below-ring-rate     62
# dtype: int64

# %% [markdown]
# Data Preparation

# %%
df.dropna(subset=['label'], inplace=True)
df.shape
# Out:
# (5764, 24)

# %%
drop_columns = ['id','gill-attachment', 'gill-spacing', 'gill-size','gill-color-rate','stalk-root', 'stalk-surface-above-ring',
 'stalk-surface-below-ring', 'stalk-color-above-ring-rate','stalk-color-below-ring-rate','veil-color-rate','veil-type']

df.drop(columns=drop_columns, inplace=True)
df.shape
# Out:
# (5764, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5764 entries, 0 to 5823
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   label              5764 non-null   object
#  1   cap-shape          5764 non-null   object
#  2   cap-surface        5737 non-null   object
#  3   bruises            5665 non-null   object
#  4   odor               5665 non-null   object
#  5   stalk-shape        5643 non-null   object
#  6   ring-number        5702 non-null   object
#  7   ring-type          5702 non-null   object
#  8   spore-print-color  5708 non-null   object
#  9   population         5708 non-null   object
#  10  habitat            5733 non-null   object
#  11  cap-color-rate     5737 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 585.4+ KB

# %%
mapping_dict = {
    "label": {
        "p": 0,
        "e": 1,
    },
}

df = df.replace(mapping_dict)
df.label.value_counts()
# Out:
# /var/folders/vc/c5yh3t2s6tgc117z_ws0m1tw0000gn/T/ipykernel_4938/3373781591.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.replace(mapping_dict)
# label
# 0    3660
# 1    2104
# Name: count, dtype: int64

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline

cat_cols=['cap-surface','bruises','odor','stalk-shape','ring-number','ring-type','spore-print-color','population','habitat']
num_cols=['cap-color-rate']

num_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='mean')),
    ('scale', StandardScaler())])

cat_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('one-hot',OneHotEncoder(handle_unknown='ignore', sparse_output=False))])
df
# Out:
#       label cap-shape cap-surface bruises odor stalk-shape ring-number  \
# 0         0         x           s       t    p           e           o
# 1         1         x           s       t    a           e           o
# 2         1         b           s       t    l           e           o
# 3         0         x           y       t    p           e           o
# 4         1         x           s       f    n           t           o
# ...     ...       ...         ...     ...  ...         ...         ...
# 5819      1         k           s       f    n           e           o
# 5820      1         x           s       f    n           e           o
# 5821      1         f           s       f    n           e           o
# 5822      0         k           y       f    y           t           o
# 5823      1         x           s       f    n           e           o
#
#      ring-type spore-print-color population habitat  cap-color-rate
# 0            p                 k          s       u             1.0
# 1            p                 n          n       g             2.0
# 2            p                 n          n       m             3.0
# 3            p                 k          s       u             3.0
# 4            e                 n          a       g             4.0
# ...        ...               ...        ...     ...             ...
# 5819         p                 b          c       l             1.0
# 5820         p                 b          v       l             1.0
# 5821         p                 b          c       l             1.0
# 5822         e                 w          v       l             1.0
# 5823         p                 o          c       l             1.0
#
# [5764 rows x 12 columns]

# %%
from sklearn.compose import ColumnTransformer

col_trans = ColumnTransformer(transformers=[
    ('num_pipeline', num_pipeline, num_cols),
    ('cat_pipeline', cat_pipeline, cat_cols)],
    n_jobs=-1)

col_trans
# Out:
# ColumnTransformer(n_jobs=-1,
#                   transformers=[('num_pipeline',
#                                  Pipeline(steps=[('impute', SimpleImputer()),
#                                                  ('scale', StandardScaler())]),
#                                  ['cap-color-rate']),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('one-hot',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['cap-surface', 'bruises', 'odor',
#                                   'stalk-shape', 'ring-number', 'ring-type',
#                                   'spore-print-color', 'population',
#                                   'habitat'])])

# %%
from sklearn.model_selection import train_test_split
y = df.pop('label')
x = df

x_train,x_test,y_train,y_test = train_test_split(x,y,stratify=y,test_size=0.2, random_state=2020)
print(x_train.shape)
print(x_test.shape)
# Out:
# (4611, 11)
# (1153, 11)

# %% [markdown]
# Random Forest

# %%
x_train
# Out:
#      cap-shape cap-surface bruises odor stalk-shape ring-number ring-type  \
# 3526         f           y       t    n           e           t         e
# 1214         f           y       t    n           t           o         p
# 1841         f           y       t    n           t           o         p
# 5548         k           s       f    f           t           o         e
# 3379         x           y       t    n           e           t         e
# ...        ...         ...     ...  ...         ...         ...       ...
# 2647         x           y       f    f           e           o         l
# 5265         k           y       f    y           t           o         e
# 5015         x           s       f    n           e           t         p
# 356          x           y       t    n           t           o         p
# 2942         f           y       f    f           e         NaN       NaN
#
#      spore-print-color population habitat  cap-color-rate
# 3526                 w          c       w             5.0
# 1214                 k          y       d             5.0
# 1841                 n          v       d             5.0
# 5548                 w          v       d             1.0
# 3379                 w          c       w             1.0
# ...                ...        ...     ...             ...
# 2647                 h          y       d             4.0
# 5265                 w          v       d             5.0
# 5015                 w          n       g             3.0
# 356                  k          y       d             5.0
# 2942               NaN        NaN       d             2.0
#
# [4611 rows x 11 columns]

# %%
import mlflow
import mlflow.sklearn
from sklearn.metrics import f1_score, accuracy_score, classification_report
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import mlflow
#       2 import mlflow.sklearn
#       3 from sklearn.metrics import f1_score, accuracy_score, classification_report
#
# File /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages/mlflow/__init__.py:34
#      31 from mlflow.version import VERSION
#      33 __version__ = VERSION
# ---> 34 from mlflow import (
#      35     artifacts,  # noqa: F401
#      36     client,  # noqa: F401
#      37     config,  # noqa: F401
#      38     data,  # noqa: F401
#      39     exceptions,  # noqa: F401
#      40     models,  # noqa: F401
#      41     projects,  # noqa: F401
#      42     tracking,  # noqa: F401
#      43 )
#      44 from mlflow.environment_variables import MLFLOW_CONFIGURE_LOGGING
#      45 from mlflow.utils.lazy_load import LazyLoader
#
# File /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages/mlflow/models/__init__.py:43
#      33 from mlflow.models.evaluation import (
#      34     EvaluationArtifact,
#      35     EvaluationMetric,
#    (...)
#      40     make_metric,
#      41 )
#      42 from mlflow.models.flavor_backend import FlavorBackend
# ---> 43 from mlflow.models.model import Model, get_model_info
#      44 from mlflow.models.python_api import build_docker
#      45 from mlflow.utils.environment import infer_pip_requirements
#
# File /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages/mlflow/models/model.py:26
#      24 from mlflow.utils.databricks_utils import get_databricks_runtime
#      25 from mlflow.utils.docstring_utils import LOG_MODEL_PARAM_DOCS, format_docstring
# ---> 26 from mlflow.utils.environment import (
#      27     _CONDA_ENV_FILE_NAME,
#      28     _PYTHON_ENV_FILE_NAME,
#      29     _REQUIREMENTS_FILE_NAME,
#      30     _add_or_overwrite_requirements,
#      31     _get_requirements_from_file,
#      32     _remove_requirements,
#      33     _write_requirements_to_file,
#      34 )
#      35 from mlflow.utils.file_utils import TempDir
#      36 from mlflow.utils.uri import (
#      37     append_to_uri_path,
#      38     get_uri_scheme,
#      39 )
#
# File /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages/mlflow/utils/environment.py:20
#      18 from mlflow.utils.os import is_windows
#      19 from mlflow.utils.process import _exec_cmd
# ---> 20 from mlflow.utils.requirements_utils import (
#      21     _infer_requirements,
#      22     _parse_requirements,
#      23     warn_dependency_requirement_mismatches,
#      24 )
#      25 from mlflow.utils.timeout import MlflowTimeoutError, run_with_timeout
#      26 from mlflow.version import VERSION
#
# File /opt/homebrew/Cellar/jupyterlab/4.1.6_1/libexec/lib/python3.12/site-packages/mlflow/utils/requirements_utils.py:20
#      17 from typing import List, NamedTuple, Optional
#      19 import importlib_metadata
# ---> 20 import pkg_resources  # noqa: TID251
#      21 from packaging.requirements import Requirement
#      22 from packaging.version import InvalidVersion, Version
#
# ModuleNotFoundError: No module named 'pkg_resources'

# %%
from sklearn.ensemble import RandomForestClassifier

local_registry = "sqlite:///mlruns.db"
mlflow.set_tracking_uri(local_registry)
experiment_id = mlflow.set_experiment('test_experiment')

def eval_metrics(actual, pred):
    accuracy = accuracy_score(actual, pred)
    return accuracy

def train_model(criterion, max_depth, min_samples_leaf,n_estimators):

    # Starting the Experiement
    with mlflow.start_run():

        # Model building
        model = RandomForestClassifier(criterion=criterion, max_depth= max_depth, min_samples_leaf = min_samples_leaf,
                                        n_estimators = n_estimators,random_state=2020)
        model_pipeline = Pipeline(steps=[
            ('col_trans', col_trans),
            ('model', model)
        ])
        model_pipeline.fit(x_train, y_train)
        y_pred = model_pipeline.predict(x_test)

        (accuracy) = eval_metrics(y_test, y_pred)

        print('Decirion tree (criterion=%s, max_depth=%d, min_samples_leaf=%d, n_estimators=%d):'%(criterion, max_depth, min_samples_leaf, n_estimators))
        print('Accuracy: {:.4f}'.format(accuracy))

        # Logging Parameters
        mlflow.log_param("criterion", criterion)
        mlflow.log_param("max_depth", max_depth)
        mlflow.log_param("min_samples_leaf", min_samples_leaf)
        mlflow.log_param("n_estimators", n_estimators)

        # Logging Metrics
        mlflow.log_metric("accuracy", accuracy_score(y_test, y_pred))

        # Model Logging
        mlflow.sklearn.log_model(model_pipeline, 'model')

        return model_pipeline

# %%
critetion = ['gini','entropy']
max_depth = [2,3,6]
min_samples_leaf = [2,5,10]
n_estimators =[100,200]

for i in range(len(critetion)):
    for j in range(len(max_depth)):
        for k in range(len(min_samples_leaf)):
            for l in range(len(n_estimators)):
                train_model(critetion[i], max_depth[j], min_samples_leaf[k], n_estimators[l])
# Out:
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9714
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9705
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9714
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9705
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9705
# Decirion tree (criterion=gini, max_depth=2, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9696
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9792
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9748
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9792
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9748
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9766
# Decirion tree (criterion=gini, max_depth=3, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9748
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9991
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9991
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9991
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9991
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9974
# Decirion tree (criterion=gini, max_depth=6, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9991
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=2, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9679
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9766
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9766
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9766
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9766
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9748
# Decirion tree (criterion=entropy, max_depth=3, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9766
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=2, n_estimators=100):
# Accuracy: 0.9991
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=2, n_estimators=200):
# Accuracy: 0.9991
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=5, n_estimators=100):
# Accuracy: 0.9991
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=5, n_estimators=200):
# Accuracy: 0.9991
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=10, n_estimators=100):
# Accuracy: 0.9983
# Decirion tree (criterion=entropy, max_depth=6, min_samples_leaf=10, n_estimators=200):
# Accuracy: 0.9983

# %%
best_run_df = mlflow.search_runs(order_by=['metrics.accuracy DESC'], max_results=10)
best_run_df
# Out:
#                              run_id experiment_id    status  \
# 0  4c7a580b179041379411a0828c76132a             1  FINISHED
# 1  471b2e800a9642afb69be63fae0ca896             1  FINISHED
# 2  dfb0dcfa51c240c5b07bf2d1b82be49e             1  FINISHED
# 3  0ec763558fa04d9aadde81772b3aa472             1  FINISHED
# 4  6147c7a6aafe466bbc2ed716be4de13c             1  FINISHED
# 5  624da1dfb2b64b4f92ebd39b094ae89c             1  FINISHED
# 6  ceb2a3760d9d40aeb334273f0d1f61de             1  FINISHED
# 7  dbaef3d74f8a46e9bf8b03c409fe395b             1  FINISHED
# 8  c6408f563e524514a9d3f377a440857d             1  FINISHED
# 9  b716a933f9d7417f9d16522e2434447c             1  FINISHED
#
#                                         artifact_uri  \
# 0  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 1  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 2  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 3  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 4  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 5  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 6  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 7  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 8  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
# 9  /Users/premikayutinatorn/Data-Sci-Eng/code/Wee...
#
#                         start_time                         end_time  \
# 0 2024-02-12 07:32:28.596000+00:00 2024-02-12 07:32:29.939000+00:00
# 1 2024-02-12 07:32:27.358000+00:00 2024-02-12 07:32:28.594000+00:00
# 2 2024-02-12 07:32:26.083000+00:00 2024-02-12 07:32:27.355000+00:00
# 3 2024-02-12 07:32:24.796000+00:00 2024-02-12 07:32:26.080000+00:00
# 4 2024-02-12 07:32:07.817000+00:00 2024-02-12 07:32:09.227000+00:00
# 5 2024-02-12 07:32:05.255000+00:00 2024-02-12 07:32:06.604000+00:00
# 6 2024-02-12 07:32:04.023000+00:00 2024-02-12 07:32:05.253000+00:00
# 7 2024-02-12 07:32:02.574000+00:00 2024-02-12 07:32:04.020000+00:00
# 8 2024-02-12 07:32:01.250000+00:00 2024-02-12 07:32:02.571000+00:00
# 9 2024-02-12 07:30:29.811000+00:00 2024-02-12 07:30:31.126000+00:00
#
#    metrics.accuracy params.min_samples_leaf params.max_depth  \
# 0          0.999133                       5                6
# 1          0.999133                       5                6
# 2          0.999133                       2                6
# 3          0.999133                       2                6
# 4          0.999133                      10                6
# 5          0.999133                       5                6
# 6          0.999133                       5                6
# 7          0.999133                       2                6
# 8          0.999133                       2                6
# 9          0.999133                       5                6
#
#   params.n_estimators params.criterion   tags.mlflow.runName  \
# 0                 200          entropy     unequaled-dog-418
# 1                 100          entropy    righteous-vole-191
# 2                 200          entropy   exultant-grouse-320
# 3                 100          entropy  agreeable-donkey-889
# 4                 200             gini         burly-koi-585
# 5                 200             gini   monumental-skunk-56
# 6                 100             gini  thoughtful-conch-802
# 7                 200             gini       powerful-ox-490
# 8                 100             gini    flawless-quail-992
# 9                 200          entropy      bouncy-trout-930
#
#                        tags.mlflow.log-model.history tags.mlflow.source.type  \
# 0  [{"run_id": "4c7a580b179041379411a0828c76132a"...                   LOCAL
# 1  [{"run_id": "471b2e800a9642afb69be63fae0ca896"...                   LOCAL
# 2  [{"run_id": "dfb0dcfa51c240c5b07bf2d1b82be49e"...                   LOCAL
# 3  [{"run_id": "0ec763558fa04d9aadde81772b3aa472"...                   LOCAL
# 4  [{"run_id": "6147c7a6aafe466bbc2ed716be4de13c"...                   LOCAL
# 5  [{"run_id": "624da1dfb2b64b4f92ebd39b094ae89c"...                   LOCAL
# 6  [{"run_id": "ceb2a3760d9d40aeb334273f0d1f61de"...                   LOCAL
# 7  [{"run_id": "dbaef3d74f8a46e9bf8b03c409fe395b"...                   LOCAL
# 8  [{"run_id": "c6408f563e524514a9d3f377a440857d"...                   LOCAL
# 9  [{"run_id": "b716a933f9d7417f9d16522e2434447c"...                   LOCAL
#
#     tags.mlflow.user                            tags.mlflow.source.name
# 0  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 1  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 2  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 3  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 4  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 5  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 6  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 7  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 8  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...
# 9  premikayutinatorn  /Users/premikayutinatorn/Library/Python/3.9/li...

# %%
run_id = str(best_run_df.loc[0, 'run_id'])
print('run_id: ', run_id)

run_id = str(best_run_df.loc[0, 'run_id'])
model_uri = f"runs:/{run_id}/model"
print('model_uri: ', model_uri)
# Out:
# run_id:  4c7a580b179041379411a0828c76132a
# model_uri:  runs:/4c7a580b179041379411a0828c76132a/model

# %%
# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(model_uri=f"runs:/{run_id}/model")

# Predict on a Pandas DataFrame.
predicted = loaded_model.predict(pd.DataFrame(x_test))

print(classification_report(y_test, predicted, target_names=['0', '1'], digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.9986    0.9993       732
#            1     0.9976    1.0000    0.9988       421
#
#     accuracy                         0.9991      1153
#    macro avg     0.9988    0.9993    0.9991      1153
# weighted avg     0.9991    0.9991    0.9991      1153

# %%
from sklearn.metrics import classification_report,confusion_matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, predicted,labels = [0,1]))
# Out:
# Confusion Matrix:
# [[731   1]
#  [  0 421]]
